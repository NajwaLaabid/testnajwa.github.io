# %% [markdown]
# # Gradient descent: simple algorithm

# %%
true_prods=['NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1'] 
gen_prods=['NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1', 'NC(=O)C1=C(N)C2=C(N=C(N3CCC(NCC(O)C4=CC=C(C5=CC=C6CC(=O)NC6=C5)C=N4)CC3)C=C2C(F)(F)F)S1']

# %%
set(gen_prods)==set(true_prods)
# Out:
# True

# %%
len(true_prods)
# Out:
# 98

# %%
[p for p in gen_prods if p not in true_prods]
# Out:
# []

# %% [markdown]
# # Gradient descent: a neural network using numpy

# %% [markdown]
# # Automatic differentiation
